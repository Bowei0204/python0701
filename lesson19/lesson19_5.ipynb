# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({'key1':['a', 'a', 'b', 'b', 'a'],
                  'key2':['one', 'two', 'one', 'two', 'one'],
                  'data1': np.random.randn(5),
                  'data2':np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.207023  0.673448
# 1    a  two -0.635777 -1.151159
# 2    b  one  1.108500  1.015825
# 3    b  two  0.197944 -0.657390
# 4    a  one  0.712726  0.578604

# %%
df.T
# Out:
#               0         1         2         3         4
# key1          a         a         b         b         a
# key2        one       two       one       two       one
# data1 -0.207023 -0.635777    1.1085  0.197944  0.712726
# data2  0.673448 -1.151159  1.015825  -0.65739  0.578604

# %%
#因為key1,key2,data1,data2沒有重覆,可以stack()
df.stack()
# Out:
# 0  key1            a
#    key2          one
#    data1   -0.207023
#    data2    0.673448
# 1  key1            a
#    key2          two
#    data1   -0.635777
#    data2   -1.151159
# 2  key1            b
#    key2          one
#    data1      1.1085
#    data2    1.015825
# 3  key1            b
#    key2          two
#    data1    0.197944
#    data2    -0.65739
# 4  key1            a
#    key2          one
#    data1    0.712726
#    data2    0.578604
# dtype: object

# %%
df1 = df.set_index(['key1','key2'])
df1
# Out:
#               data1     data2
# key1 key2
# a    one  -0.207023  0.673448
#      two  -0.635777 -1.151159
# b    one   1.108500  1.015825
#      two   0.197944 -0.657390
# a    one   0.712726  0.578604

# %%
#會出錯,因為值有重覆
#df1.unstack(level='key1')
#df1.unstack(level='key2')

# %%
df2 = df.groupby(by=['key1','key2']).max()
df2
# Out:
#               data1     data2
# key1 key2
# a    one   0.712726  0.673448
#      two  -0.635777 -1.151159
# b    one   1.108500  1.015825
#      two   0.197944 -0.657390

# %%
df2.unstack(level='key2')
# Out:
#          data1               data2
# key2       one       two       one       two
# key1
# a     0.712726 -0.635777  0.673448 -1.151159
# b     1.108500  0.197944  1.015825 -0.657390

# %%
df2.unstack(level='key1')
# Out:
#          data1               data2
# key1         a         b         a         b
# key2
# one   0.712726  1.108500  0.673448  1.015825
# two  -0.635777  0.197944 -1.151159 -0.657390
