# %%
import numpy as np

# %%
np.linspace(1,50,num=500)

# %%
a= np.random.randint(50,101,size=(50,5))
a

# %%
import matplotlib.pyplot as plt
t = np.arange(0,5,0.1)
y1 = np.sin(t * np.pi)
y2 = np.cos(t * np.pi)

figure = plt.figure()
axes = figure.add_subplot()
axes.plot(y1)
axes.plot(y2)

plt.show()
