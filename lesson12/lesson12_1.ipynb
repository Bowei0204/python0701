# %%
from os.path import abspath,dirname,join
file_path = join(dirname(abspath(__name__)),'data','people.csv')
file_path
# Out:
# '/workspaces/python0701/lesson12/data/people.csv'

# %%
from csv import DictReader
from pprint import pprint

with open(file_path,encoding='utf-8',newline='') as file:
    reader = DictReader(file)
    pprint(list(file))
# Out:
# ['姓名,身高,體重,BMI,狀態\r\n',
#  '王展人,160,75,29.3,輕度肥胖\r\n',
#  '陳向愛,154,53,22.35,體重正常\r\n',
#  '陳冠竹,160,61,23.83,體重正常\r\n',
#  '艾巧夫,161,65,25.08,體重過重\r\n',
#  '陳向愛,160,88,34.37,中度肥胖\r\n',
#  '胡芳瑜,186,73,21.1,體重正常\r\n',
#  '景歡燦,182,65,19.62,體重正常\r\n',
#  '張伊映,190,69,19.11,體重正常\r\n',
#  '劉佳佩,160,60,23.44,體重正常\r\n',
#  '黃江旭,177,63,20.11,體重正常\r\n',
#  '邱亭君,174,88,29.07,輕度肥胖\r\n',
#  '陳怡伶,157,52,21.1,體重正常\r\n',
#  '黃志福,179,67,20.91,體重正常\r\n',
#  '陳信念,155,80,33.3,中度肥胖\r\n',
#  '胡姿婷,187,85,24.31,體重過重\r\n',
#  '馬彥文,174,57,18.83,體重正常\r\n',
#  '孫宜珊,184,51,15.06,體重過輕\r\n',
#  '鄭憲定,152,54,23.37,體重正常\r\n',
#  '林康亮,165,66,24.24,體重過重\r\n',
#  '陳得映,166,60,21.77,體重正常\r\n',
#  '陳信宏,178,83,26.2,體重過重\r\n',
#  '鄧哲榮,169,62,21.71,體重正常\r\n',
#  '李政成,168,58,20.55,體重正常\r\n',
#  '許淑婷,186,71,20.52,體重正常\r\n',
#  '黎惠雯,178,81,25.56,體重過重\r\n',
#  '方雅慧,187,58,16.59,體重過輕\r\n',
#  '鄭淑珍,163,84,31.62,中度肥胖\r\n',
#  '黃佩芬,177,88,28.09,輕度肥胖\r\n',
#  '林柏洋,189,77,21.56,體重正常\r\n',
#  '陳家維,158,83,33.25,中度肥胖\r\n',
#  '蕭淑華,152,61,26.4,體重過重\r\n',
#  '劉旭士,152,68,29.43,輕度肥胖\r\n',
#  '郭致恬,168,56,19.84,體重正常\r\n',
#  '黃必琪,153,88,37.59,重度肥胖\r\n',
#  '戚亨,151,59,25.88,體重過重\r\n',
#  '林建勳,160,83,32.42,中度肥胖\r\n',
#  '龐皓芳,188,63,17.82,體重過輕\r\n',
#  '黃翔杰,188,79,22.35,體重正常\r\n',
#  '黃淑芬,158,60,24.03,體重過重\r\n',
#  '陳淑萍,168,57,20.2,體重正常\r\n',
#  '游一鈺,185,81,23.67,體重正常\r\n',
#  '鄧哲榮,154,74,31.2,中度肥胖\r\n',
#  '張軒宸,150,87,38.67,重度肥胖\r\n',
#  '鄭憲定,180,66,20.37,體重正常\r\n',
#  '張韋成,181,62,18.92,體重正常\r\n',
#  '周家銘,187,65,18.59,體重正常\r\n',
#  '簡美君,161,52,20.06,體重正常\r\n',
#  '余丞苓,188,72,20.37,體重正常\r\n',
#  '趙宛真,161,72,27.78,輕度肥胖\r\n',
#  '黃善迪,189,83,23.24,體重正常\r\n']

# %%
import pandas as pd
df = pd.read_csv('/workspaces/python0701/lesson12/data/people.csv')
df
# Out:
#      姓名   身高  體重    BMI    狀態
# 0   王展人  160  75  29.30  輕度肥胖
# 1   陳向愛  154  53  22.35  體重正常
# 2   陳冠竹  160  61  23.83  體重正常
# 3   艾巧夫  161  65  25.08  體重過重
# 4   陳向愛  160  88  34.37  中度肥胖
# 5   胡芳瑜  186  73  21.10  體重正常
# 6   景歡燦  182  65  19.62  體重正常
# 7   張伊映  190  69  19.11  體重正常
# 8   劉佳佩  160  60  23.44  體重正常
# 9   黃江旭  177  63  20.11  體重正常
# 10  邱亭君  174  88  29.07  輕度肥胖
# 11  陳怡伶  157  52  21.10  體重正常
# 12  黃志福  179  67  20.91  體重正常
# 13  陳信念  155  80  33.30  中度肥胖
# 14  胡姿婷  187  85  24.31  體重過重
# 15  馬彥文  174  57  18.83  體重正常
# 16  孫宜珊  184  51  15.06  體重過輕
# 17  鄭憲定  152  54  23.37  體重正常
# 18  林康亮  165  66  24.24  體重過重
# 19  陳得映  166  60  21.77  體重正常
# 20  陳信宏  178  83  26.20  體重過重
# 21  鄧哲榮  169  62  21.71  體重正常
# 22  李政成  168  58  20.55  體重正常
# 23  許淑婷  186  71  20.52  體重正常
# 24  黎惠雯  178  81  25.56  體重過重
# 25  方雅慧  187  58  16.59  體重過輕
# 26  鄭淑珍  163  84  31.62  中度肥胖
# 27  黃佩芬  177  88  28.09  輕度肥胖
# 28  林柏洋  189  77  21.56  體重正常
# 29  陳家維  158  83  33.25  中度肥胖
# 30  蕭淑華  152  61  26.40  體重過重
# 31  劉旭士  152  68  29.43  輕度肥胖
# 32  郭致恬  168  56  19.84  體重正常
# 33  黃必琪  153  88  37.59  重度肥胖
# 34   戚亨  151  59  25.88  體重過重
# 35  林建勳  160  83  32.42  中度肥胖
# 36  龐皓芳  188  63  17.82  體重過輕
# 37  黃翔杰  188  79  22.35  體重正常
# 38  黃淑芬  158  60  24.03  體重過重
# 39  陳淑萍  168  57  20.20  體重正常
# 40  游一鈺  185  81  23.67  體重正常
# 41  鄧哲榮  154  74  31.20  中度肥胖
# 42  張軒宸  150  87  38.67  重度肥胖
# 43  鄭憲定  180  66  20.37  體重正常
# 44  張韋成  181  62  18.92  體重正常
# 45  周家銘  187  65  18.59  體重正常
# 46  簡美君  161  52  20.06  體重正常
# 47  余丞苓  188  72  20.37  體重正常
# 48  趙宛真  161  72  27.78  輕度肥胖
# 49  黃善迪  189  83  23.24  體重正常
