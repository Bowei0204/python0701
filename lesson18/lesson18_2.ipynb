# %%
import numpy as np
import pandas as pd
import random
with open("names.txt",encoding="utf-8") as file:
    content = file.read()

names_list = content.split()
names = random.choices(names_list,k=50)
names   

scores = np.random.randint(50,101,size=(50,5))
student_df = pd.DataFrame(scores,
             columns=['國文','英文','數學','地理','歷史'],
             index=names)
student_df
# Out:
#       國文   英文   數學   地理   歷史
# 邱亭君   91   58   75   70   56
# 謝佳穎   72   72   58   98   90
# 黃志福   50   58   97   76   77
# 林佳蓉   59   87   91   99   98
# 趙家豪   83   74   86   61   55
# 陳嘉淑   55   98   58   82   55
# 金宜芳   52   72   80   77   58
# 劉嘉泰   99   74   71   80   74
# 黃心航   89   51   61   59   89
# 鄭琇亞   70   61   99   89   77
# 黃偉剛   73   53   72   96   89
# 郭淑枝   92   72   95   89   67
# 蘇凡菁   73   64   73   96   97
# 王梅劭   84   65   81   81   75
# 黃婷婷   86   99   96   95   77
# 張彥博   81   65   72   95   98
# 黃志福   91   55   58   70   94
# 羅幸娥   87   82   87   81   70
# 賴苑禾   95   54   98   75   81
# 胡淑貞   71   52   98   84   93
# 許淑婷   83   51   85   99   62
# 朱惠儀   79   50  100   85   60
# 林淑安   50   53   88   55   73
# 黃靜怡   58   88   56   88   60
# 朱士弘   78   76   59   58   84
# 陳信宏   74   86   67   78   83
# 李彥伸   96   52   77   52  100
# 溫法堯   54   82   70  100   96
# 王德城   52   59   75   83   82
# 蘇婷婷   99   70   78   99   71
# 張軒宸   52   93   56   74   56
# 龐皓芳   93   99   90   70   92
# 劉依婷   94   90   67   53   88
# 方筠紹   97   91   61   73   65
# 陳淑萍   99   79   63   53   71
# 黃婷婷   84   68   90   96   90
# 唐雪豪   98   66   73   58   83
# 陳信念   80   96   86   77   79
# 劉旭士   98   90   98   51   53
# 溫重意   96   71   51   65   83
# 林志成   71   57   65   83   50
# 魏秋萍   74   65   86   90   78
# 謝哲維   79   65   69   64  100
# 郭淑枝   79   55   75   84  100
# 陳向愛   97   53   61   76   96
# 林建宏  100  100   98   60   97
# 林昱芳   63   53   87   85   68
# 趙家豪   83   97   76   57   52
# 余月修   82   99   67   91   60
# 李佳彥   74   89   71   55   70

# %%
from pandas import Series,DataFrame
def fun3(s):
    sum = s.sum()
    mean = s.mean()
    count = s[s<60].count()
    values = s[s<60].index.values
    return Series([sum,mean,count,values],index=['總分','平均','不及格數','不及格科目'])

student_df.apply(fun3,axis=1)
# Out:
#       總分    平均  不及格數         不及格科目
# 邱亭君  350  70.0     2      [英文, 歷史]
# 謝佳穎  390  78.0     1          [數學]
# 黃志福  358  71.6     2      [國文, 英文]
# 林佳蓉  434  86.8     1          [國文]
# 趙家豪  359  71.8     1          [歷史]
# 陳嘉淑  348  69.6     3  [國文, 數學, 歷史]
# 金宜芳  339  67.8     2      [國文, 歷史]
# 劉嘉泰  398  79.6     0            []
# 黃心航  349  69.8     2      [英文, 地理]
# 鄭琇亞  396  79.2     0            []
# 黃偉剛  383  76.6     1          [英文]
# 郭淑枝  415  83.0     0            []
# 蘇凡菁  403  80.6     0            []
# 王梅劭  386  77.2     0            []
# 黃婷婷  453  90.6     0            []
# 張彥博  411  82.2     0            []
# 黃志福  368  73.6     2      [英文, 數學]
# 羅幸娥  407  81.4     0            []
# 賴苑禾  403  80.6     1          [英文]
# 胡淑貞  398  79.6     1          [英文]
# 許淑婷  380  76.0     1          [英文]
# 朱惠儀  374  74.8     1          [英文]
# 林淑安  319  63.8     3  [國文, 英文, 地理]
# 黃靜怡  350  70.0     2      [國文, 數學]
# 朱士弘  355  71.0     2      [數學, 地理]
# 陳信宏  388  77.6     0            []
# 李彥伸  377  75.4     2      [英文, 地理]
# 溫法堯  402  80.4     1          [國文]
# 王德城  351  70.2     2      [國文, 英文]
# 蘇婷婷  417  83.4     0            []
# 張軒宸  331  66.2     3  [國文, 數學, 歷史]
# 龐皓芳  444  88.8     0            []
# 劉依婷  392  78.4     1          [地理]
# 方筠紹  387  77.4     0            []
# 陳淑萍  365  73.0     1          [地理]
# 黃婷婷  428  85.6     0            []
# 唐雪豪  378  75.6     1          [地理]
# 陳信念  418  83.6     0            []
# 劉旭士  390  78.0     2      [地理, 歷史]
# 溫重意  366  73.2     1          [數學]
# 林志成  326  65.2     2      [英文, 歷史]
# 魏秋萍  393  78.6     0            []
# 謝哲維  377  75.4     0            []
# 郭淑枝  393  78.6     1          [英文]
# 陳向愛  383  76.6     1          [英文]
# 林建宏  455  91.0     0            []
# 林昱芳  356  71.2     1          [英文]
# 趙家豪  365  73.0     2      [地理, 歷史]
# 余月修  399  79.8     0            []
# 李佳彥  359  71.8     1          [地理]
